# %% [markdown]
# <a href="https://colab.research.google.com/github/Shailenderyedugani/CV_MANIT/blob/main/CV_ASSIGNMENT_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
img = cv2.imread('d.jpg')

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=650x433 at 0x7F4837BB4DA0>

# %%
img.shape
# Out:
# (433, 650, 3)

# %%
width,height = 400,400
imgresize = cv2.resize(img,(width,height),interpolation=cv2.INTER_CUBIC)

# %%
cv2_imshow(imgresize)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F4835A2A5F8>

# %%
imgresize1 = cv2.resize(img,(width,height),interpolation=cv2.INTER_NEAREST)
cv2_imshow(imgresize1)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F4837286A20>

# %%
imgresize2 = cv2.resize(img,(width,height),interpolation=cv2.INTER_LINEAR)
cv2_imshow(imgresize2)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F4837286780>

# %%
imgresize3 = cv2.resize(img,(width,height),interpolation=cv2.INTER_AREA)
cv2_imshow(imgresize3)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F48372865C0>

# %%
imgresize4 = cv2.resize(img,(width,height),interpolation=cv2.INTER_LINEAR_EXACT)
cv2_imshow(imgresize4)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F4837286CC0>

# %%
width,height = 800,600
imgresize5 = cv2.resize(img,(width,height),interpolation=cv2.INTER_CUBIC)
cv2_imshow(imgresize5)
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F48359BABA8>

# %%
imgresize6 = cv2.resize(img,(width,height),interpolation=cv2.INTER_LINEAR_EXACT)
cv2_imshow(imgresize6)
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F4835A2AF60>
